# %%
# Dependencies

import pandas as pd
import numpy as np
import glob
import os
import timeit                                # To check performance
from datetime import datetime, date, time, timedelta
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
# Export clean CSV file to master CSV file

tic = timeit.default_timer()                            # Monitor performance

routes_df = pd.read_csv("Routes/routes_to_plot.csv", index_col=None, header=0)

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to import CSV file: {round(toc - tic, 2)}')
routes_df
# Out:
# Time (in seconds) to import CSV file: 0.0
#      Total_Rides  Start_Station  End_Station  \
# 0            477             18            1
# 1            434            211          217
# 2            427              1           18
# 3            342            174          183
# 4            335             41            3
# ..           ...            ...          ...
# 940           71            182          180
# 941           71            267           18
# 942           71            271           23
# 943           71            272           18
# 944           71            295          299
#
#                                Start_Station_Name  Start_Station_Lat  \
# 0                             18 REFORMA-RIO RHIN          19.428880
# 1                              211 NEWTON-HORACIO          19.433607
# 2                           1 RIO SENA-RIO BALSAS          19.433571
# 3    174 JOAQUÍN GARCIA-IGNACIO MANUEL ALTAMIRANO          19.441110
# 4                  41 REFORMA-AV. DE LA REPUBLICA          19.435637
# ..                                            ...                ...
# 940                       182 PROGRESO-ASTRONOMOS          19.402089
# 941        267 AV. JESÜS GARCÏA-CARLOS J. MENESES          19.443735
# 942                   271 AV. CENTRAL-J. MENESES           19.443928
# 943                   272 AV. CENTRAL-J. MENESES           19.443556
# 944                 295 ANAXÁGORAS-EJE 4 SUR XOLA          19.396328
#
#      Start_Station_Lon      Start_Colonia  \
# 0           -99.164176         Cuauhtemoc
# 1           -99.188528            Polanco
# 2           -99.167809         Cuauhtemoc
# 3           -99.161640         San Rafael
# 4           -99.150137         Tabacalera
# ..                 ...                ...
# 940         -99.171390          Hipodromo
# 941         -99.152203         Buenavista
# 942         -99.152525         Buenavista
# 943         -99.152556         Buenavista
# 944         -99.156871  Narvarte Poniente
#
#                          End_Station_Name  End_Station_Lat  End_Station_Lon  \
# 0                   1 RIO SENA-RIO BALSAS        19.433571       -99.167809
# 1                  217 EULER-AV. HORACIO         19.432888       -99.183605
# 2                     18 REFORMA-RIO RHIN        19.428880       -99.164176
# 3     183 GABINO BARRERA-GUILLERMO PRIETO        19.437670       -99.164020
# 4                   3 REFORMA-INSURGENTES        19.431655       -99.158668
# ..                                    ...              ...              ...
# 940        180 QUINTANA ROO-VILLA HERMOSA        19.404554       -99.169953
# 941                   18 REFORMA-RIO RHIN        19.428880       -99.164176
# 942                      23 REFORMA-PRAGA        19.425170       -99.171050
# 943                   18 REFORMA-RIO RHIN        19.428880       -99.164176
# 944  299 ROMERO DE TERREROS-MIER Y PESADO        19.394601       -99.165054
#
#           End_Colonia
# 0          Cuauhtemoc
# 1             Polanco
# 2          Cuauhtemoc
# 3          San Rafael
# 4              Juarez
# ..                ...
# 940         Hipodromo
# 941        Cuauhtemoc
# 942            Juarez
# 943        Cuauhtemoc
# 944  Del Valle Centro
#
# [945 rows x 11 columns]

# %%
routes_df.to_json("Routes/routes_to_plot.json", orient = 'index')
